# %%
from PIL import Image
import cv2 
import imageio
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML, display
import tabulate
import pandas as pd

# %%
pic = imageio.imread('grey.png')

# %%
plt.figure(figsize = (15,15))
plt.imshow(pic)

# %%
print('Tinggi gambar {}'.format(pic.shape[0]))
print('Lebar gambar {}'.format(pic.shape[1]))
print('Image size {}'.format(pic.size))
print('Total Pixel ',int(format(pic.shape[0])) * int(format(pic.shape[1])))
# Out:
# Tinggi gambar 450
# Lebar gambar 301
# Image size 406350
# Total Pixel  135450

# %%
(n, bins, patches) = plt.hist(pic.ravel(), 256,[0,256])
# plt.show()

# %%
# len(n)
table = [None] * len(n)
i = 0
pixel = int(format(pic.shape[0])) * int(format(pic.shape[1]))
while(i <= 255):
    table[i] = [bins[i],n[i], int(n[1])/pixel]
    #data = [[bins[i], n[i], int(n[1])/pixel]]
    #pd.DataFrame(data, columns=["i", "Ni", "hi=ni/n"])
    #print("i ",bins[i])
    #display(HTML(tabulate.tabulate(table, tablefmt='html')))
    i = i + 1
#table
display(HTML(tabulate.tabulate(table, tablefmt='html')))
#pd.DataFrame(table, columns=["i", "Ni", "hi=ni/n"])
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">  0</td><td style="text-align: right;">22038</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  1</td><td style="text-align: right;">16263</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  2</td><td style="text-align: right;"> 7533</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  3</td><td style="text-align: right;"> 4494</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  4</td><td style="text-align: right;"> 3072</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  5</td><td style="text-align: right;"> 2454</td><td style="text-align: right;">0.120066</td></tr>
# <tr><td style="text-align: right;">  6</td><td style="text-align: right;"> 2124</td><td style="text-align: right;">0.120066</td></tr>
# ...
